# %%
import os
import pandas as pd

# %%
print(os.getcwd())
os.chdir("../../soge-home/projects/mistral/mans4178/schools")
print(os.getcwd())
# Out:
# /hn01-home/mans4178
# /lustre/soge1/projects/mistral/mans4178/schools

# %%
# Read in output csv of metrics

# %%
ETH_csv = pd.read_csv("validation/model_comp/cdf_metrics__ETH.csv", index_col=0)
MWI_csv = pd.read_csv("validation/model_comp/cdf_metrics__MWI.csv", index_col=0)
NGA_csv = pd.read_csv("validation/model_comp/cdf_metrics__NGA.csv", index_col=0)
TZA_csv = pd.read_csv("validation/model_comp/cdf_metrics__TZA.csv", index_col=0)
UGA_csv = pd.read_csv("validation/model_comp/cdf_metrics__UGA.csv", index_col=0)

# %%
ALL_csv = pd.concat([ETH_csv, MWI_csv, NGA_csv, TZA_csv, UGA_csv], ignore_index=True)

# %%
type(ALL_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
ALL_csv.to_csv("validation/model_comp/cdf_metrics__ALL.csv")
